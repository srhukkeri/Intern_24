# %%
import selenium 
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
import requests
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
import re
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
option = Options()
option.add_argument("--disable-infobars")

option.add_argument("start-maximized")

option.add_argument("--disable-extensions")

driver = webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32 (1)\chromedriver.exe', chrome_options=option)

driver.get("https://trak.in/")
driver.maximize_window()
time.sleep(2)
search=driver.find_element_by_xpath('//a[@title="http://trak.in/india-startup-funding-investment-2015/"]').click()

# close_popup_button = driver.find_element_by_xpath('//div[@id="ad_position_box"]').click()
driver.get("https://trak.in/")
search=driver.find_element_by_xpath('//a[@title="http://trak.in/india-startup-funding-investment-2015/"]').click()

# %%
soup= BeautifulSoup(driver.page_source , 'lxml')

# %%
tables1 = soup.find_all('table', class_="tablepress tablepress-id-56 dataTable no-footer")
tables2 = soup.find_all('table', class_="tablepress tablepress-id-55 dataTable no-footer")
tables3 = soup.find_all('table', class_="tablepress tablepress-id-54 dataTable no-footer")

# Step 3: Read tables with Pandas read_html()
data1 = pd.read_html(str(tables1))
data2 = pd.read_html(str(tables2))
data3 = pd.read_html(str(tables3))

print(f'Total tables: {len(data1)}')
print(f'Total tables: {len(data2)}')
print(f'Total tables: {len(data3)}')
# Out:
# Total tables: 2
# Total tables: 2
# Total tables: 2

# %%
print(data1)
print(data2)
print(data3)
# Out:
# [Empty DataFrame
# Columns: [Sr. No., Date (dd/mm/yyyy), Startup Name, Industry / Vertical, Sub-Vertical, City / Location, Investors' Name, Investment Type, Amount (In USD)]
# Index: [],    Sr. No. Date (dd/mm/yyyy) Startup Name Industry / Vertical  \
# 0        1        04/03/2021    DealShare          E-commerce
# 1        2        31/03/2021     Uniphore          Technology
# 2        3        30/03/2021        Dunzo          E-commerce
# 3        4        30/03/2021       BYJU’S            Edu-tech
# 4        5        23/03/2021  SkilloVilla            Edu-tech
# 5        6        25/03/2021     CityMall          E-commerce
# 6        7        26/03/2021        DotPe             FinTech
#
#                                         Sub-Vertical    City / Location  \
# 0                           Online shopping platform  Jaipur, Rajasthan
# 1            Conversational Service Automation (CSA)          Palo Alto
# ...
