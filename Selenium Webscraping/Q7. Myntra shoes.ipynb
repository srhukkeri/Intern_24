# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
import requests
warnings.filterwarnings("ignore")
import time

driver = webdriver.Chrome(r'C:\Users\s.rajendra.hukkeri\Downloads\chromedriver_win32\chromedriver.exe')
url= "https://www.myntra.com/shoes"
driver.get(url)
search = driver.find_element_by_xpath('//label[@class="common-customCheckbox"]').click()
time.sleep(2)
price=driver.find_elements_by_xpath("//label[@class='common-customCheckbox vertical-filters-label']")[7].click()

time.sleep(2)
href_urls = [my_elem.get_attribute("href") for my_elem in driver.find_elements_by_css_selector("ul.pagination-container > a")]
time.sleep(2)

brand=[]
des=[]
prices=[]

brand_name = driver.find_elements_by_xpath('//h3[@class="product-brand"]')
for l in brand_name:
    brand.append(l.text)
brand

describe = driver.find_elements_by_xpath('//h4[@class="product-product"]')
for j in describe:
    des.append(j.text)
des

price = driver.find_elements_by_xpath('//div[@class="product-price"]')
for k in price:
    prices.append(k.text)
prices

href_urls = driver.find_element_by_xpath('//a[@href="https://www.myntra.com/shoes?f=Color%3ABlack_36454f&rf=Price%3A7224.0_14149.0_7224.0%20TO%2014149.0&p=2"]').click()

print(len(prices))
print(len(brand))
print(len(des))

data=pd.DataFrame()
data['Brand Name']=brand
data['Description']=des
data['Price']=prices
data
# Out:
# 50
# 50
# 50
#               Brand Name                                Description  \
# 0                   Nike                 Men Winflo 7 Running Shoes
# 1                   Nike             Men Blazer Court Skateboarding
# 2                   Puma              Men Jamming 2.0 Running Shoes
# 3                   Puma                          Men Running Shoes
# 4                   ALDO                  Men Woven Design Sneakers
# 5                   Nike                  Men Air Max Dawn Sneakers
# 6                   Puma             Men Deviate Nitro Running Shoe
# 7         Tommy Hilfiger                       Men Leather Sneakers
# 8         Tommy Hilfiger                       Men Leather Sneakers
# 9                  ASICS                        Women Running Shoes
# 10                  Puma                Men Electrify Nitro Running
# 11              Skechers             Men Go Run Hyper Burst Running
# 12        Tommy Hilfiger                       Men Textured Loafers
# ...
