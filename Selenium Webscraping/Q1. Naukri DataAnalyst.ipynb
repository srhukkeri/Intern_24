# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
import requests

driver = webdriver.Chrome(r'C:\Users\s.rajendra.hukkeri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
url = "https://www.naukri.com/"
driver.get(url)

search = driver.find_element_by_class_name('suggestor-input')
search.send_keys("Data Analyst")

loc = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[3]/div/div/div[3]/div/div/div/input')
loc.send_keys('Bangalore')

driver.find_element_by_xpath('//div[@class="qsbSubmit"]').click()

# %%
title = driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
len(title) 
titles=[]
for i in title:
    titles.append(i.text)
titles
# Out:
# ['QA Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst - Data Modeling/Database Design',
#  'Data analyst',
#  'Data Analyst',
#  'Financial Data Analyst',
#  'Data Analyst',
#  'OYO Rooms - Data Analyst / Business Analyst',
#  'Senior Data Analyst',
#  'Senior Data Analyst',
#  'Senior Data Analyst - Collibra',
#  'Data Analyst - Python/SQL',
#  'Data Analyst - IT',
#  'Staff Data Analyst (MINT)',
#  'Financial Data Analyst',
#  'Data Analyst',
#  'Marketing Data Analyst',
#  'Reference Data Analyst']

# %%
company= driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
len(company)
list_company=[]
for j in company:
    list_company.append(j.text)
list_company
# Out:
# ['Ralph Lauren',
#  'Flipkart',
#  'Ericsson Global Services',
#  'Flipkart',
#  'K & R Enterprises',
#  'GSK India',
#  'GSK India',
#  "Moody's",
#  'Aldius Consulting Services Pvt Ltd (Paramantra)',
#  'OyoRooms',
#  'Liventus',
#  'Cerner',
#  'Shell',
#  'Affine',
#  'Yespired',
#  'Walmart',
#  "Moody's",
#  'Slice',
#  'Branch Metrics',
#  'Deutsche Bank']

# %%
yrs=[]
year = driver.find_elements_by_xpath('//span[contains(@title,"Yrs")]')
len(year)
for k in year:
    yrs.append(k.text)
yrs
# Out:
# ['0-3 Yrs',
#  '4-6 Yrs',
#  '10-20 Yrs',
#  '1-6 Yrs',
#  '4-6 Yrs',
#  '5-9 Yrs',
#  '7-10 Yrs',
#  '0-2 Yrs',
#  '0-2 Yrs',
#  '2-6 Yrs',
#  '5-8 Yrs',
#  '2-5 Yrs',
#  '8-12 Yrs',
#  '3-5 Yrs',
#  '3-8 Yrs',
#  '3-7 Yrs',
#  '1-3 Yrs',
#  '1-5 Yrs',
#  '2-5 Yrs',
#  '2-5 Yrs']

# %%
location=[]
loca = driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
for l in loca:
    location.append(l.text)
location
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#  'Remote',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
data= pd.DataFrame()
data['Job_Title']=titles
data['Job_Location']=location
data['Years_Of_Exp']=yrs
data['Company']=list_company
data
# Out:
#                                             Job_Title  \
# 0                                     QA Data Analyst
# 1                                 Senior Data Analyst
# 2                                        Data Analyst
# 3                                        Data Analyst
# 4   Senior Data Analyst - Data Modeling/Database D...
# 5                                        Data analyst
# 6                                        Data Analyst
# 7                              Financial Data Analyst
# 8                                        Data Analyst
# 9         OYO Rooms - Data Analyst / Business Analyst
# 10                                Senior Data Analyst
# 11                                Senior Data Analyst
# 12                     Senior Data Analyst - Collibra
# 13                          Data Analyst - Python/SQL
# 14                                  Data Analyst - IT
# 15                          Staff Data Analyst (MINT)
# 16                             Financial Data Analyst
# 17                                       Data Analyst
# 18                             Marketing Data Analyst
# 19                             Reference Data Analyst
#
#                                          Job_Location Years_Of_Exp  \
# 0                                 Bangalore/Bengaluru      0-3 Yrs
# 1                                 Bangalore/Bengaluru      4-6 Yrs
# 2                                 Bangalore/Bengaluru    10-20 Yrs
# 3                                 Bangalore/Bengaluru      1-6 Yrs
# 4                                 Bangalore/Bengaluru      4-6 Yrs
# 5                                 Bangalore/Bengaluru      5-9 Yrs
# 6                                 Bangalore/Bengaluru     7-10 Yrs
# 7                                 Bangalore/Bengaluru      0-2 Yrs
# 8                                 Bangalore/Bengaluru      0-2 Yrs
# 9   Bangalore/Bengaluru, Delhi / NCR, Mumbai (All ...      2-6 Yrs
# 10                                             Remote      5-8 Yrs
# 11                                Bangalore/Bengaluru      2-5 Yrs
# 12                                Bangalore/Bengaluru     8-12 Yrs
# 13                                Bangalore/Bengaluru      3-5 Yrs
# 14                                Bangalore/Bengaluru      3-8 Yrs
# 15                                Bangalore/Bengaluru      3-7 Yrs
# 16                                Bangalore/Bengaluru      1-3 Yrs
# 17                                Bangalore/Bengaluru      1-5 Yrs
# 18                                Bangalore/Bengaluru      2-5 Yrs
# 19                                Bangalore/Bengaluru      2-5 Yrs
#
#                                             Company
# 0                                      Ralph Lauren
# 1                                          Flipkart
# 2                          Ericsson Global Services
# 3                                          Flipkart
# 4                                 K & R Enterprises
# 5                                         GSK India
# 6                                         GSK India
# 7                                           Moody's
# 8   Aldius Consulting Services Pvt Ltd (Paramantra)
# 9                                          OyoRooms
# 10                                         Liventus
# 11                                           Cerner
# 12                                            Shell
# 13                                           Affine
# 14                                         Yespired
# 15                                          Walmart
# 16                                          Moody's
# 17                                            Slice
# 18                                   Branch Metrics
# 19                                    Deutsche Bank
