# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
import requests

driver = webdriver.Chrome(r'C:\Users\s.rajendra.hukkeri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
url= "https://www.flipkart.com/"
driver.get(url)
button = driver.find_element_by_xpath('/html/body/div[2]/div/div/button').click()
search=driver.find_element_by_class_name("_3704LK")
search.send_keys("sunglasses")
search1=driver.find_element_by_class_name("L0Z3Pu").click()      # search
time.sleep(5)

href_urls = [my_elem.get_attribute("href") for my_elem in driver.find_elements_by_css_selector("nav.yFHi8N > a")]
brand=[]
des=[]
prices=[]
offers=[]

for i in range(0,3):
    page = requests.get(url)   #url page
    driver = webdriver.Chrome(r'C:\Users\s.rajendra.hukkeri\Downloads\chromedriver_win32\chromedriver.exe')
    url= href_urls[i]
    driver.get(url)
    time.sleep(2) 
    brand_name = driver.find_elements_by_xpath('//div[@class="_2WkVRV"]')
    for l in brand_name:
        brand.append(l.text)
    
    describe = driver.find_elements_by_xpath('//a[@class="IRpwTa"]')
    for j in describe:
        if j.text == ' ':
            des.append("No offer found")
        else:
            des.append(j.text)
    
    price = driver.find_elements_by_xpath('//div[@class="_30jeq3"]')
    for k in price:
        prices.append(k.text)
        
    offer = driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]')
    for m in offer:
        offers.append(m.text)


df = pd.DataFrame()
df['Brand']= brand
df['Price']= prices
df['Offer']= offers
df['Description']=des
df.head(100)
# Out:
#              Brand Price    Offer  \
# 0           GANSTA  ₹148  91% off
# 1           GANSTA  ₹234  88% off
# 2        Elligator  ₹198  92% off
# 3             SRPM  ₹148  88% off
# 4           SUNBEE  ₹193  85% off
# ..             ...   ...      ...
# 95  kingsunglasses  ₹108  89% off
# 96            hipe  ₹147  85% off
# 97        Fastrack  ₹844  15% off
# 98  ROZZETTA CRAFT  ₹292  85% off
# 99          GANSTA  ₹185  85% off
#
#                                           Description
# 0   UV Protection, Riding Glasses Wayfarer Sunglas...
# 1               UV Protection Aviator Sunglasses (57)
# 2                 UV Protection Round Sunglasses (54)
# 3              UV Protection Wayfarer Sunglasses (50)
# 4   UV Protection, Polarized Wayfarer Sunglasses (...
# ..                                                ...
# 95  UV Protection, Mirrored Wayfarer Sunglasses (F...
# 96  UV Protection, Mirrored, Gradient, Riding Glas...
# 97                UV Protection Round Sunglasses (55)
# 98  UV Protection, Gradient Round Sunglasses (Free...
# 99    UV Protection, Gradient Aviator Sunglasses (57)
#
# [100 rows x 4 columns]

# %%
print(len(offers))
print(len(prices))
print(len(brand))
print(len(des))
# Out:
# 120
# 120
# 120
# 120
